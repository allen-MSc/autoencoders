# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transform
import torch.nn.functional as F
import matplotlib.pyplot as plt
from tqdm import tqdm
import utils
torch.cuda.empty_cache()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
def get_high_low_loaders(data_set):
  train_idx_h = [h for h in range(len(data_set.targets)) if data_set.targets[h] == 0]
  train_idx_l = [l for l in range(len(data_set.targets)) if data_set.targets[l] == 1]

  # high resolution
  train_set_h = torch.utils.data.Subset(data_set, train_idx_h)
  train_loader_h = torch.utils.data.DataLoader(dataset=train_set_h, batch_size=batch_size, shuffle=False)

  # low resolution
  train_set_l = torch.utils.data.Subset(data_set, train_idx_l)
  train_loader_l = torch.utils.data.DataLoader(dataset=train_set_l, batch_size=batch_size, shuffle=False)

  return train_loader_h, train_loader_l

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)

batch_size = 32

img_transform = transform.Compose([transform.ToTensor()]) 

# Training Set
train_set =  torchvision.datasets.ImageFolder('/content/drive/MyDrive/Public/images/train', img_transform)
# train_loader = torch.utils.data.DataLoader(dataset=train_set, batch_size=batch_size, shuffle=True, pin_memory=True)
print(train_set)

# Testing Set
test_set =  torchvision.datasets.ImageFolder('/content/drive/MyDrive/Public/images/val', img_transform)
# test_loader = torch.utils.data.DataLoader(dataset=test_set, batch_size=batch_size, shuffle=True, pin_memory=True)
print(test_set)
# Out:
# cuda:0
# Dataset ImageFolder
#     Number of datapoints: 1370
#     Root location: /content/drive/MyDrive/Public/images/train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )
# Dataset ImageFolder
#     Number of datapoints: 340
#     Root location: /content/drive/MyDrive/Public/images/val
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )

# %%
init_dim = 256
encoder_conv1 = utils.size_output_layer(init_dim, 4, 2, 1)
print("encoder_conv1:", encoder_conv1)

encoder_conv2 = utils.size_output_layer(encoder_conv1, 4, 2, 1)
print("encoder_conv2:", encoder_conv2)

encoder_conv3 = utils.size_output_layer(encoder_conv2, 4, 2, 1)
print("encoder_conv3:", encoder_conv3)

decoder_conv1 = utils.size_output_layer_up(encoder_conv3, 4, 2, 1)
print("\ndecoder_conv1:", decoder_conv1)

decoder_conv2 = utils.size_output_layer_up(decoder_conv1, 4, 2, 1)
print("decoder_conv2:", decoder_conv2)
# Out:
# encoder_conv1: 128
# encoder_conv2: 64
# encoder_conv3: 32
#
# decoder_conv1: 65
# decoder_conv2: 131

# %%
class Encoder(nn.Module):
  def __init__(self):
    super(Encoder, self).__init__()

    self.conv1 = nn.Sequential(
      nn.Conv2d(in_channels=3, out_channels=128, kernel_size=4, stride=2, padding=1),
      nn.BatchNorm2d(128),
      nn.ReLU()
    )

    self.conv2 = nn.Sequential(
      nn.Conv2d(in_channels=128, out_channels=256, kernel_size=4, stride=2, padding=1),
      nn.BatchNorm2d(256),
      nn.ReLU()
    )

    self.conv3 = nn.Sequential(
      nn.Conv2d(in_channels=256, out_channels=512, kernel_size=4, stride=2, padding=1),
      nn.BatchNorm2d(512),
      nn.ReLU()
    )

    self.fc = nn.Sequential(
        # nn.Linear(in_features=512*32*32, out_features=1024),
        nn.Linear(in_features=512*32*32, out_features=30)
    )

  def forward(self, image):
    self.out1 = self.conv1(image)
    self.out2 = self.conv2(self.out1)
    self.out3 = self.conv3(self.out2)
    self.out4 = self.out3.view(self.out3.size(0), -1)
    z = self.fc(self.out4)
    return z

class Decoder(nn.Module):
  def __init__(self):
    super(Decoder, self).__init__()

    self.fc = nn.Sequential(
        # nn.Linear(in_features=30,out_features=1024),
        nn.Linear(in_features=30,out_features=512*32*32)
    )

    self.convTran1 = nn.Sequential(
        nn.ConvTranspose2d(in_channels=2*512, out_channels=256, kernel_size=4, stride=2, padding=1),
        nn.BatchNorm2d(256),
        nn.ReLU()
    )

    self.convTran2 = nn.Sequential(
        nn.ConvTranspose2d(in_channels=2*256, out_channels=128, kernel_size=4, stride=2, padding=1),
        nn.BatchNorm2d(128),
        nn.ReLU()
    )
  
    self.convTran3 = nn.Sequential(
        nn.ConvTranspose2d(in_channels=2*128, out_channels=64, kernel_size=4, stride=2, padding=1),
        nn.BatchNorm2d(64),
        nn.ReLU()
    )

    self.convTran4 = nn.Sequential(
        nn.ConvTranspose2d(in_channels=64, out_channels=3, kernel_size=3, stride=1, padding=1),
        # nn.BatchNorm2d(3),
        nn.ReLU()
    )
   
  def forward(self, latent, encoder):
    out = self.fc(latent)
    out = out.view(out.size(0), 512, 32, 32)
    out = self.convTran1(torch.cat([encoder.out3, out], dim=1))
    out = self.convTran2(torch.cat([encoder.out2, out], dim=1))
    out = self.convTran3(torch.cat([encoder.out1, out], dim=1))
    out = torch.tanh(self.convTran4(out))
    return out

# %%
class Autoencoder(nn.Module):
   def __init__(self):
        super(Autoencoder, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()

   def forward(self, x):
        latent = self.encoder(x)
        x_recon = self.decoder(latent, self.encoder)
        return  x_recon

# %%
def train(model, images_set, Epochs, loss_fn):

    images_high_loader, images_low_loader = get_high_low_loaders(images_set)

    train_loss_avg = []
    for epoch in range(Epochs):
      train_loss_avg.append(0)
      num_batches = 0

      images_high_it = iter(images_high_loader)
    
      for image_batch, _ in tqdm(images_low_loader):
          image_batch = image_batch.to(device)
          
          image_batch_recon = model(image_batch)

          image_batch_high, _ = next(images_high_it)
          image_batch_high = image_batch_high.to(device)
          
          loss = loss_fn(image_batch_recon, image_batch_high)
          
          optimizer.zero_grad()
          loss.backward()
          optimizer.step()
          
          train_loss_avg[-1] += loss.item()
          num_batches += 1
          
      train_loss_avg[-1] /= num_batches
      print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, Epochs, train_loss_avg[-1]))
    return train_loss_avg

# %%
autoencoder = Autoencoder()
autoencoder.to(device)

print(autoencoder)

learning_rate = 0.001
loss = nn.MSELoss()
optimizer = torch.optim.Adam(params=autoencoder.parameters(), lr=learning_rate, weight_decay=1e-5)

autoencoder.train()
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (conv1): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv3): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=524288, out_features=30, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (fc): Sequential(
#       (0): Linear(in_features=30, out_features=524288, bias=True)
#     )
#     (convTran1): Sequential(
#       (0): ConvTranspose2d(1024, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (convTran2): Sequential(
#       (0): ConvTranspose2d(512, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (convTran3): Sequential(
#       (0): ConvTranspose2d(256, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (convTran4): Sequential(
#       (0): ConvTranspose2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#     )
#   )
# )
# Autoencoder(
#   (encoder): Encoder(
#     (conv1): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv3): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=524288, out_features=30, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (fc): Sequential(
#       (0): Linear(in_features=30, out_features=524288, bias=True)
#     )
#     (convTran1): Sequential(
#       (0): ConvTranspose2d(1024, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (convTran2): Sequential(
#       (0): ConvTranspose2d(512, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (convTran3): Sequential(
#       (0): ConvTranspose2d(256, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (convTran4): Sequential(
#       (0): ConvTranspose2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#     )
#   )
# )

# %%
loss_result = train(autoencoder, train_set, 10, loss)
# Out:
# 100%|██████████| 22/22 [01:01<00:00,  2.82s/it]
# Epoch [1 / 10] average reconstruction error: 0.103445
# 100%|██████████| 22/22 [01:02<00:00,  2.84s/it]
# Epoch [2 / 10] average reconstruction error: 0.059402
# 100%|██████████| 22/22 [01:02<00:00,  2.83s/it]
# Epoch [3 / 10] average reconstruction error: 0.019886
# 100%|██████████| 22/22 [01:02<00:00,  2.83s/it]
# Epoch [4 / 10] average reconstruction error: 0.011416
# 100%|██████████| 22/22 [01:02<00:00,  2.83s/it]
# Epoch [5 / 10] average reconstruction error: 0.007304
# 100%|██████████| 22/22 [01:02<00:00,  2.83s/it]
# Epoch [6 / 10] average reconstruction error: 0.005417
# 100%|██████████| 22/22 [01:02<00:00,  2.83s/it]
# Epoch [7 / 10] average reconstruction error: 0.004567
# 100%|██████████| 22/22 [01:02<00:00,  2.83s/it]
# Epoch [8 / 10] average reconstruction error: 0.004160
# 100%|██████████| 22/22 [01:02<00:00,  2.83s/it]
# Epoch [9 / 10] average reconstruction error: 0.003841
# 100%|██████████| 22/22 [01:02<00:00,  2.83s/it]
# Epoch [10 / 10] average reconstruction error: 0.003738

# %%
fig = plt.figure()
plt.plot(loss_result)
plt.xlabel('Epochs')
plt.ylabel('Reconstruction error')
plt.show()

# %%
test_high_loader, test_low_loader = get_high_low_loaders(test_set)

autoencoder.eval()

with torch.no_grad():
  image, label = iter(test_low_loader).next()

  image = image.to(device)
  label = label.to(device)

  z = autoencoder.encoder(image)
  z = z.to(device)

  decodificado = autoencoder.decoder(z, autoencoder.encoder)
  decodificado = decodificado.to('cpu')

# %%
idx_img = 30;
images_l, _ = iter(test_low_loader).next()
images_h, _ = iter(test_high_loader).next()

fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharex=True, figsize=(20, 20))
ax0.set_title('Test Image (low resolution)')
ax0.imshow(transform.ToPILImage()(images_l[idx_img]))

ax1.set_title('Predicted Image')
ax1.imshow(transform.ToPILImage()(decodificado[idx_img]))

ax2.set_title('Original Image (high resolution)')
ax2.imshow(transform.ToPILImage()(images_h[idx_img]))
